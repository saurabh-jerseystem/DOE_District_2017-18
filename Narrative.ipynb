# %%
import os
import pandas as pd
import numpy as np

#df = pd.read_excel('narrative_raw.xlsx')
df = pd.read_csv('raw.csv',index_col = False, dtype = {"CountyCode": str,"DistrictCode": str,"SchoolCode": str})
df.head(2)
# Out:
#   CountyCode CountyName DistrictCode   DistrictName Highlight1 Highlight2  \
# 0         01   ATLANTIC         0010   ABSECON CITY        NaN        NaN
# 1         01   ATLANTIC         0110  ATLANTIC CITY        NaN        NaN
#
#   Highlight3                                            Mission Awards  \
# 0        NaN                                                NaN    NaN
# 1        NaN  The Atlantic City District recognizes the urge...    NaN
#
#                                              Courses  ... Health  \
# 0                                                NaN  ...    NaN
# 1  The Lesley University Literacy Framework and R...  ...    NaN
#
#                                               Parent ClimateSurveyUsed  \
# 0                                                NaN               NaN
# 1  The District's has Title I Parent Resource Cen...               Yes
#
#                                  WholsSurveyed  \
# 0                                          NaN
# 1  Students, Parents, Administrators, Teachers
#
#                                     ClimateNarrative Facilities SchoolSafety  \
# 0                                                NaN        NaN          NaN
# 1  The district conducts a school climate survey ...        NaN          NaN
#
#   TechnologySTEM EarlyChildhood  \
# 0            NaN            NaN
# 1            NaN            NaN
#
#                                     OtherInformation
# 0                                                NaN
# 1  The Pennsylvania Avenue School Library has rec...
#
# [2 rows x 27 columns]

# %% [markdown]
# ### Check number of columns and rows

# %%
df.shape
# Out:
# (674, 27)

# %% [markdown]
# ### Adding columns from 2016-17 table

# %%
df['Superintendent'] = 'NA'
df['Address1'] = 'NA'
df['Address2'] = 'NA'
df['City'] = 'NA'
df['State'] = 'NA'
df['ZIP'] = 'NA'
df['Phone'] = 'NA'
df['Email'] = 'NA'
df['Website'] = 'NA'
df['Facebook'] = 'NA'
df['Twitter'] = 'NA'
df['Year'] = '2017-18'

# %% [markdown]
# ### Check if columns are added properly

# %%
df.head()
# Out:
#   CountyCode CountyName DistrictCode              DistrictName  \
# 0         01   ATLANTIC         0010              ABSECON CITY
# 1         01   ATLANTIC         0110             ATLANTIC CITY
# 2         01   ATLANTIC         0120    ATLANTIC CO VOCATIONAL
# 3         01   ATLANTIC         0125  ATLANTIC CO SPECIAL SERV
# 4         01   ATLANTIC         0570           BRIGANTINE CITY
#
#                                           Highlight1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  The Brigantine Public School District is a com...
#
#                                           Highlight2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  We have been recognized with New Jersey School...
#
#                                           Highlight3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  As part of our drive to support the developmen...
#
#                                              Mission  \
# 0                                                NaN
# 1  The Atlantic City District recognizes the urge...
# 2  The mission of the Atlantic County Vocational ...
# 3                                                NaN
# 4  Our vision is to create world-class public sch...
#
#                                               Awards  \
# 0                                                NaN
# 1                                                NaN
# 2  The success of the academic and career and tec...
# 3                                                NaN
# 4  We pride ourselves on passion for teaching and...
#
#                                              Courses  ... Address2 City State  \
# 0                                                NaN  ...       NA   NA    NA
# 1  The Lesley University Literacy Framework and R...  ...       NA   NA    NA
# 2  The Atlantic County Vocational School District...  ...       NA   NA    NA
# 3                                                NaN  ...       NA   NA    NA
# 4  Curriculums are progressive, meet individual n...  ...       NA   NA    NA
#
#   ZIP Phone Email Website Facebook Twitter     Year
# 0  NA    NA    NA      NA       NA      NA  2017-18
# 1  NA    NA    NA      NA       NA      NA  2017-18
# 2  NA    NA    NA      NA       NA      NA  2017-18
# 3  NA    NA    NA      NA       NA      NA  2017-18
# 4  NA    NA    NA      NA       NA      NA  2017-18
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Check missing values

# %%
df.isnull().sum()
# Out:
# CountyCode             0
# CountyName             0
# DistrictCode           0
# DistrictName           0
# Highlight1           380
# Highlight2           410
# Highlight3           444
# Mission               98
# Awards               266
# Courses              181
# Sports               364
# SportsNarrative      387
# Clubs                257
# Programs             269
# Staff                184
# Postsecondary        484
# Supports             207
# Health               260
# Parent               185
# ClimateSurveyUsed    408
# WholsSurveyed        423
# ClimateNarrative     438
# Facilities           265
# SchoolSafety         349
# TechnologySTEM       364
# EarlyChildhood       479
# OtherInformation     336
# Superintendent         0
# Address1               0
# Address2               0
# City                   0
# State                  0
# ZIP                    0
# Phone                  0
# Email                  0
# Website                0
# Facebook               0
# Twitter                0
# Year                   0
# dtype: int64

# %% [markdown]
# ### Fill missing values

# %%
df = df.fillna('NA')

# %% [markdown]
# ### Check again if missing values are dealt properly

# %%
df.isnull().sum()
# Out:
# CountyCode           0
# CountyName           0
# DistrictCode         0
# DistrictName         0
# Highlight1           0
# Highlight2           0
# Highlight3           0
# Mission              0
# Awards               0
# Courses              0
# Sports               0
# SportsNarrative      0
# Clubs                0
# Programs             0
# Staff                0
# Postsecondary        0
# Supports             0
# Health               0
# Parent               0
# ClimateSurveyUsed    0
# WholsSurveyed        0
# ClimateNarrative     0
# Facilities           0
# SchoolSafety         0
# TechnologySTEM       0
# EarlyChildhood       0
# OtherInformation     0
# Superintendent       0
# Address1             0
# Address2             0
# City                 0
# State                0
# ZIP                  0
# Phone                0
# Email                0
# Website              0
# Facebook             0
# Twitter              0
# Year                 0
# dtype: int64

# %% [markdown]
# ### Check for meaningless values such as '**','N'

# %%
#df['School Requires Comprehensive Support - As of 2017-18'] = df['School Requires Comprehensive Support - As of 2017-18'].replace('**','NA')
#df['School Requires Comprehensive Support - As of 2017-18'] = df['School Requires Comprehensive Support - As of 2017-18'].replace('N','NA')

# %% [markdown]
# ### Check Data types of all columns

# %%
df.dtypes
# Out:
# CountyCode           object
# CountyName           object
# DistrictCode         object
# DistrictName         object
# Highlight1           object
# Highlight2           object
# Highlight3           object
# Mission              object
# Awards               object
# Courses              object
# Sports               object
# SportsNarrative      object
# Clubs                object
# Programs             object
# Staff                object
# Postsecondary        object
# Supports             object
# Health               object
# Parent               object
# ClimateSurveyUsed    object
# WholsSurveyed        object
# ClimateNarrative     object
# Facilities           object
# SchoolSafety         object
# TechnologySTEM       object
# EarlyChildhood       object
# OtherInformation     object
# Superintendent       object
# Address1             object
# Address2             object
# City                 object
# State                object
# ZIP                  object
# Phone                object
# Email                object
# Website              object
# Facebook             object
# Twitter              object
# Year                 object
# dtype: object

# %% [markdown]
# ### Change Data types

# %%
#df["Female"] = df["Female"].astype(float)

# %% [markdown]
# ### Check the changed data types

# %%
#df.dtypes

# %% [markdown]
# ### Get a look at final data

# %%
df.head()
# Out:
#   CountyCode CountyName DistrictCode              DistrictName  \
# 0         01   ATLANTIC         0010              ABSECON CITY
# 1         01   ATLANTIC         0110             ATLANTIC CITY
# 2         01   ATLANTIC         0120    ATLANTIC CO VOCATIONAL
# 3         01   ATLANTIC         0125  ATLANTIC CO SPECIAL SERV
# 4         01   ATLANTIC         0570           BRIGANTINE CITY
#
#                                           Highlight1  \
# 0                                                 NA
# 1                                                 NA
# 2                                                 NA
# 3                                                 NA
# 4  The Brigantine Public School District is a com...
#
#                                           Highlight2  \
# 0                                                 NA
# 1                                                 NA
# 2                                                 NA
# 3                                                 NA
# 4  We have been recognized with New Jersey School...
#
#                                           Highlight3  \
# 0                                                 NA
# 1                                                 NA
# 2                                                 NA
# 3                                                 NA
# 4  As part of our drive to support the developmen...
#
#                                              Mission  \
# 0                                                 NA
# 1  The Atlantic City District recognizes the urge...
# 2  The mission of the Atlantic County Vocational ...
# 3                                                 NA
# 4  Our vision is to create world-class public sch...
#
#                                               Awards  \
# 0                                                 NA
# 1                                                 NA
# 2  The success of the academic and career and tec...
# 3                                                 NA
# 4  We pride ourselves on passion for teaching and...
#
#                                              Courses  ... Address2 City State  \
# 0                                                 NA  ...       NA   NA    NA
# 1  The Lesley University Literacy Framework and R...  ...       NA   NA    NA
# 2  The Atlantic County Vocational School District...  ...       NA   NA    NA
# 3                                                 NA  ...       NA   NA    NA
# 4  Curriculums are progressive, meet individual n...  ...       NA   NA    NA
#
#   ZIP Phone Email Website Facebook Twitter     Year
# 0  NA    NA    NA      NA       NA      NA  2017-18
# 1  NA    NA    NA      NA       NA      NA  2017-18
# 2  NA    NA    NA      NA       NA      NA  2017-18
# 3  NA    NA    NA      NA       NA      NA  2017-18
# 4  NA    NA    NA      NA       NA      NA  2017-18
#
# [5 rows x 39 columns]

# %%
#df1.to_csv(df1.csv)
df.to_csv('Narrative.csv', encoding='utf-8', index=False)

# %%
#x= df1.to_excel('output1.xlsx')  # doctest: +SKIP
